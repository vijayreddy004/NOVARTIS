# %%
import pandas as pd
import numpy as np
raw_df = pd.read_excel('usecase_4_.xlsx')

# %%
completed = raw_df[raw_df['Study Status']=="COMPLETED"]

# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta
def calculate_months_difference(row):
    start_date = row['Start Date']
    end_date = row['Completion Date']
    if pd.isnull(start_date) or pd.isnull(end_date):
        return None
    delta = relativedelta(end_date, start_date)
    return delta.years * 12 + delta.months
completed['Time Interval'] = completed.apply(lambda row: calculate_months_difference(row), axis=1)
# Out:
# C:\Users\vijay\AppData\Local\Temp\ipykernel_13496\1326641746.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   completed['Time Interval'] = completed.apply(lambda row: calculate_months_difference(row), axis=1)

# %%
completed.dropna(subset=['Time Interval'],inplace=True)
# Out:
# C:\Users\vijay\AppData\Local\Temp\ipykernel_13496\3447854969.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   completed.dropna(subset=['Time Interval'],inplace=True)

# %%
clean_comp = completed.drop(columns=['Study Title','Study URL','Study Status','Study Results','Interventions','NCT Number','Study Design','Completion Date','Start Date','Primary Completion Date','First Posted','Results First Posted','Last Update Posted','Other IDs'])

# %%
clean_comp['Target'] = clean_comp['Study Recruitment Rate'] * clean_comp['Time Interval']

# %%
new = clean_comp#.drop(columns=['Study Recruitment Rate','Time Interval'])
new.head()
# Out:
#                                        Brief Summary  \
# 0  NK cells from patients with malignant diseases...
# 1  The purpose of this study is to determine safe...
# 2  This is a multi-site study with plerixafor in ...
# 3  This study has the objective to demonstrate th...
# 4  The purpose of this two part study is to test ...
#
#                                           Conditions  \
# 0                             Acute Myeloid Leukemia
# 1                                Diabetic Foot Ulcer
# 2  Ewing's Sarcoma/Soft Tissue Sarcoma|Neuroblast...
# 3                        Poisoning by Scorpion Sting
# 4                                     Malaria, Vivax
#
#                             Primary Outcome Measures  \
# 0  Determine the safety / maximum tolerated dose ...
# 1  Safety Outcome, Number of participant with adv...
# 2  Proportion of patients achieving at least a do...
# 3  To demonstrate the effectiveness of Alacramyn ...
# 4  Number of Participants With Recurrence-free Ef...
#
#                           Secondary Outcome Measures  \
# 0  Evaluate the therapeutic efficacy of Neukoplas...
# 1  Efficacy Outcome, To evaluate the percent chan...
# 2  Number of days of apheresis required to reach ...
# 3  Effectiveness of Alacramyn NAMO in the treatme...
# 4  Number of Participants With Recurrence-free Ef...
#
#                               Other Outcome Measures  \
# 0                                                NaN
# 1  Pharmacokinetic Measurements, Pharmacokinetic ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                            Sponsor  \
# 0                ImmunityBio, Inc.
# 1  Novalead Pharma Private Limited
# 2        Genzyme, a Sanofi Company
# 3   Instituto Bioclon S.A. de C.V.
# 4                  GlaxoSmithKline
#
#                                        Collaborators  Sex  \
# 0                                                NaN  ALL
# 1                                                NaN  ALL
# 2                                             Sanofi  ALL
# 3  Centre Antipoison et de Pharmacovigilane du Ma...  ALL
# 4                      Medicines for Malaria Venture  ALL
#
#                          Age         Phases  Enrollment Funder Type  \
# 0         ADULT, OLDER_ADULT         PHASE1           7    INDUSTRY
# 1         ADULT, OLDER_ADULT  PHASE1|PHASE2          44    INDUSTRY
# 2               CHILD, ADULT  PHASE1|PHASE2          46    INDUSTRY
# 3                      CHILD  PHASE2|PHASE3          56    INDUSTRY
# 4  CHILD, ADULT, OLDER_ADULT         PHASE2         851    INDUSTRY
#
#        Study Type                                          Locations  \
# 0  INTERVENTIONAL  UPMC Cancer Center - Hillman Cancer Center, Pi...
# 1  INTERVENTIONAL  VA New England Health Care Division, Providenc...
# 2  INTERVENTIONAL  Investigational Site Number 51, Gent, 9000, Be...
# 3  INTERVENTIONAL  CHU Hassan II de F̬s, F̬s, Morocco|H̫pital ...
# 4  INTERVENTIONAL  GSK Investigational Site, Bandarban, Banglades...
#
#    Study Recruitment Rate  Time Interval     Target
# 0                0.551598           12.0   6.619171
# 1                0.443157           19.0   8.419978
# 2                0.044558           38.0   1.693205
# 3                7.279202            3.0  21.837607
# 4                1.969008           30.0  59.070250

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
enc_col = ['Phases','Sex','Age','Funder Type','Study Type']
for i in enc_col:
    new[i] = encoder.fit_transform(new[i])
new.head()
# Out:
#                                        Brief Summary  \
# 0  NK cells from patients with malignant diseases...
# 1  The purpose of this study is to determine safe...
# 2  This is a multi-site study with plerixafor in ...
# 3  This study has the objective to demonstrate th...
# 4  The purpose of this two part study is to test ...
#
#                                           Conditions  \
# 0                             Acute Myeloid Leukemia
# 1                                Diabetic Foot Ulcer
# 2  Ewing's Sarcoma/Soft Tissue Sarcoma|Neuroblast...
# 3                        Poisoning by Scorpion Sting
# 4                                     Malaria, Vivax
#
#                             Primary Outcome Measures  \
# 0  Determine the safety / maximum tolerated dose ...
# 1  Safety Outcome, Number of participant with adv...
# 2  Proportion of patients achieving at least a do...
# 3  To demonstrate the effectiveness of Alacramyn ...
# 4  Number of Participants With Recurrence-free Ef...
#
#                           Secondary Outcome Measures  \
# 0  Evaluate the therapeutic efficacy of Neukoplas...
# 1  Efficacy Outcome, To evaluate the percent chan...
# 2  Number of days of apheresis required to reach ...
# 3  Effectiveness of Alacramyn NAMO in the treatme...
# 4  Number of Participants With Recurrence-free Ef...
#
#                               Other Outcome Measures  \
# 0                                                NaN
# 1  Pharmacokinetic Measurements, Pharmacokinetic ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                            Sponsor  \
# 0                ImmunityBio, Inc.
# 1  Novalead Pharma Private Limited
# 2        Genzyme, a Sanofi Company
# 3   Instituto Bioclon S.A. de C.V.
# 4                  GlaxoSmithKline
#
#                                        Collaborators  Sex  Age  Phases  \
# 0                                                NaN    0    1       0
# 1                                                NaN    0    1       1
# 2                                             Sanofi    0    3       1
# 3  Centre Antipoison et de Pharmacovigilane du Ma...    0    2       3
# 4                      Medicines for Malaria Venture    0    4       2
#
#    Enrollment  Funder Type  Study Type  \
# 0           7            2           0
# 1          44            2           0
# 2          46            2           0
# 3          56            2           0
# 4         851            2           0
#
#                                            Locations  Study Recruitment Rate  \
# 0  UPMC Cancer Center - Hillman Cancer Center, Pi...                0.551598
# 1  VA New England Health Care Division, Providenc...                0.443157
# 2  Investigational Site Number 51, Gent, 9000, Be...                0.044558
# 3  CHU Hassan II de F̬s, F̬s, Morocco|H̫pital ...                7.279202
# 4  GSK Investigational Site, Bandarban, Banglades...                1.969008
#
#    Time Interval     Target
# 0           12.0   6.619171
# 1           19.0   8.419978
# 2           38.0   1.693205
# 3            3.0  21.837607
# 4           30.0  59.070250

# %%
new = new.fillna(' ')

# %%
new['Main'] = new['Brief Summary'] + ' ' + new['Conditions'] + ' ' + new['Primary Outcome Measures'] + ' ' + new['Secondary Outcome Measures'] + ' ' + new['Other Outcome Measures'] + ' ' + new['Sponsor'] + ' ' + new['Collaborators']
new['Main'].head()
# Out:
# 0    NK cells from patients with malignant diseases...
# 1    The purpose of this study is to determine safe...
# 2    This is a multi-site study with plerixafor in ...
# 3    This study has the objective to demonstrate th...
# 4    The purpose of this two part study is to test ...
# Name: Main, dtype: object

# %%
new_clean = new.drop(columns=['Brief Summary','Conditions','Primary Outcome Measures','Secondary Outcome Measures','Other Outcome Measures','Sponsor','Collaborators'])

# %%
new_clean['Location List'] = new_clean['Locations'].str.split('|')
new_clean['Location Count'] = new_clean['Location List'].apply(len)

# %%
new_clean.head()
# Out:
#    Sex  Age  Phases  Enrollment  Funder Type  Study Type  \
# 0    0    1       0           7            2           0
# 1    0    1       1          44            2           0
# 2    0    3       1          46            2           0
# 3    0    2       3          56            2           0
# 4    0    4       2         851            2           0
#
#                                            Locations  Study Recruitment Rate  \
# 0  UPMC Cancer Center - Hillman Cancer Center, Pi...                0.551598
# 1  VA New England Health Care Division, Providenc...                0.443157
# 2  Investigational Site Number 51, Gent, 9000, Be...                0.044558
# 3  CHU Hassan II de F̬s, F̬s, Morocco|H̫pital ...                7.279202
# 4  GSK Investigational Site, Bandarban, Banglades...                1.969008
#
#    Time Interval     Target  \
# 0           12.0   6.619171
# 1           19.0   8.419978
# 2           38.0   1.693205
# 3            3.0  21.837607
# 4           30.0  59.070250
#
#                                                 Main  \
# 0  NK cells from patients with malignant diseases...
# 1  The purpose of this study is to determine safe...
# 2  This is a multi-site study with plerixafor in ...
# 3  This study has the objective to demonstrate th...
# 4  The purpose of this two part study is to test ...
#
#                                        Location List  Location Count
# 0  [UPMC Cancer Center - Hillman Cancer Center, P...               1
# 1  [VA New England Health Care Division, Providen...               5
# 2  [Investigational Site Number 51, Gent, 9000, B...              27
# 3  [CHU Hassan II de F̬s, F̬s, Morocco, H̫pita...               2
# 4  [GSK Investigational Site, Bandarban, Banglade...              14

# %%
new_clean['Final Target'] = new_clean['Target'] * new_clean['Location Count']

# %%
new_clean['Final Target'] = new_clean['Final Target'].round().astype(int)

# %%
df = new_clean.drop(columns=['Locations','Location List','Final Target'])
df.head()#,'Location Count','Target'
# Out:
#    Sex  Age  Phases  Enrollment  Funder Type  Study Type  \
# 0    0    1       0           7            2           0
# 1    0    1       1          44            2           0
# 2    0    3       1          46            2           0
# 3    0    2       3          56            2           0
# 4    0    4       2         851            2           0
#
#    Study Recruitment Rate  Time Interval     Target  \
# 0                0.551598           12.0   6.619171
# 1                0.443157           19.0   8.419978
# 2                0.044558           38.0   1.693205
# 3                7.279202            3.0  21.837607
# 4                1.969008           30.0  59.070250
#
#                                                 Main  Location Count
# 0  NK cells from patients with malignant diseases...               1
# 1  The purpose of this study is to determine safe...               5
# 2  This is a multi-site study with plerixafor in ...              27
# 3  This study has the objective to demonstrate th...               2
# 4  The purpose of this two part study is to test ...              14

# %%
df.shape
df.reset_index(inplace=True)

# %%
import re
def remove_non_alpha(text):
    return re.sub(r'[^a-zA-Z]', ' ', text)
df['Main'] = df['Main'].apply(remove_non_alpha)

# %%
df['Main'].head()
# Out:
# 0    NK cells from patients with malignant diseases...
# 1    The purpose of this study is to determine safe...
# 2    This is a multi site study with plerixafor in ...
# 3    This study has the objective to demonstrate th...
# 4    The purpose of this two part study is to test ...
# Name: Main, dtype: object

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
lematizer = WordNetLemmatizer()
corpus = []
for i in range(0,len(df)):
        review = df['Main'][i]
        review = review.lower()
        review = review.split()
        review = [lematizer.lemmatize(word) for word in review if not word in stopwords.words('english')]
        review = ' '.join(review)
        corpus.append(review)

# %%
with open('corpus.txt', 'w') as f:
    for item in corpus:
        f.write(f"{item}\n")

# %%
loaded_text_array = []
with open('corpus.txt', 'r') as f:
    for line in f:
        loaded_text_array.append(line.strip())

# %%
X = df.drop(columns=['Main','Study Recruitment Rate','Target','index'])
X['Text'] = loaded_text_array
Y = df['Study Recruitment Rate']

# %%
X.head()
# Out:
#    Sex  Age  Phases  Enrollment  Funder Type  Study Type  Time Interval  \
# 0    0    1       0           7            2           0           12.0
# 1    0    1       1          44            2           0           19.0
# 2    0    3       1          46            2           0           38.0
# 3    0    2       3          56            2           0            3.0
# 4    0    4       2         851            2           0           30.0
#
#    Location Count                                               Text
# 0               1  nk cell patient malignant disease often functi...
# 1               5  purpose study determine safety efficacy new ge...
# 2              27  multi site study plerixafor pediatric cancer p...
# 3               2  study objective demonstrate effectiveness alac...
# 4              14  purpose two part study test safety efficacy ta...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from xgboost import XGBRegressor
nlp_pipeline2 = Pipeline([('Vectorizer', TfidfVectorizer())])
preprocessor2 = ColumnTransformer(transformers=[('Text',nlp_pipeline2,'Text')])
final_pipeline2 = Pipeline([('preprocessor', preprocessor2),('Regressor',XGBRegressor())])
final_pipeline2.fit(X,Y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('Text',
#                                                   Pipeline(steps=[('Vectorizer',
#                                                                    TfidfVectorizer())]),
#                                                   'Text')])),
#                 ('Regressor',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_bynode=None,
#                               colsample_bytree=None, device=None,
#                               early_stopping_rounds=None,
#                               enable_categorical=False, eval_metric=None,
#                               feature_types=None, gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=None,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=None, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=None, n_jobs=None,
#                               num_parallel_tree=None, random_state=None, ...))])

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from xgboost import XGBRegressor
nlp_pipeline1 = Pipeline([('Vectorizer', TfidfVectorizer())])
preprocessor1 = ColumnTransformer(transformers=[('Text',nlp_pipeline1,'Text')])
final_pipeline1 = Pipeline([('preprocessor', preprocessor1),('Regressor',XGBRegressor())])
final_pipeline1.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('Text',
#                                                   Pipeline(steps=[('Vectorizer',
#                                                                    TfidfVectorizer())]),
#                                                   'Text')])),
#                 ('Regressor',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_bynode=None,
#                               colsample_bytree=None, device=None,
#                               early_stopping_rounds=None,
#                               enable_categorical=False, eval_metric=None,
#                               feature_types=None, gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=None,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=None, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=None, n_jobs=None,
#                               num_parallel_tree=None, random_state=None, ...))])

# %%
y_pred1 = final_pipeline1.predict(x_train)
y_pred2 = final_pipeline2.predict(X)

# %%
y_test_pred1 = final_pipeline1.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error,root_mean_squared_error,r2_score
mean_absolute_error(y_train,y_pred1),mean_absolute_error(Y,y_pred2),mean_absolute_error(y_test,y_test_pred1)
# Out:
# (3.640824759678518, 4.1139375991797795, 7.571444124165739)

# %%
root_mean_squared_error(y_train,y_pred1),r2_score(y_train,y_pred1),r2_score(Y,y_pred2),root_mean_squared_error(Y,y_pred2)
# Out:
# (5.923293608836296, 0.9408811386372762, 0.9537601818540293, 7.033124795030077)

# %%
root_mean_squared_error(y_test,y_test_pred1),r2_score(y_test,y_test_pred1)
# Out:
# (53.373694629529055, 0.041922974516757194)
